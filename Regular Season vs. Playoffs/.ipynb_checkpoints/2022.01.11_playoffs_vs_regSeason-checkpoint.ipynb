# %%
import numpy as np
import pandas as pd

# %%
from nba_api.stats.static import teams

[(team['id'], team['abbreviation']) for team in teams.get_teams()]
# Out:
# [(1610612737, 'ATL'),
#  (1610612738, 'BOS'),
#  (1610612739, 'CLE'),
#  (1610612740, 'NOP'),
#  (1610612741, 'CHI'),
#  (1610612742, 'DAL'),
#  (1610612743, 'DEN'),
#  (1610612744, 'GSW'),
#  (1610612745, 'HOU'),
#  (1610612746, 'LAC'),
#  (1610612747, 'LAL'),
#  (1610612748, 'MIA'),
#  (1610612749, 'MIL'),
#  (1610612750, 'MIN'),
#  (1610612751, 'BKN'),
#  (1610612752, 'NYK'),
#  (1610612753, 'ORL'),
#  (1610612754, 'IND'),
#  (1610612755, 'PHI'),
#  (1610612756, 'PHX'),
#  (1610612757, 'POR'),
#  (1610612758, 'SAC'),
#  (1610612759, 'SAS'),
#  (1610612760, 'OKC'),
#  (1610612761, 'TOR'),
#  (1610612762, 'UTA'),
#  (1610612763, 'MEM'),
#  (1610612764, 'WAS'),
#  (1610612765, 'DET'),
#  (1610612766, 'CHA')]

# %%
from nba_api.stats.endpoints import teamyearbyyearstats

temp = teamyearbyyearstats.TeamYearByYearStats(team_id='1610612764') 

temp.get_data_frames()[0]
# Out:
#        TEAM_ID   TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612764     Chicago   Packers  1961-62  80    18      62    0.225
# 1   1610612764     Chicago   Zephyrs  1962-63  80    25      55    0.313
# 2   1610612764   Baltimore   Bullets  1963-64  80    31      49    0.388
# 3   1610612764   Baltimore   Bullets  1964-65  80    37      43    0.463
# 4   1610612764   Baltimore   Bullets  1965-66  80    38      42    0.475
# ..         ...         ...       ...      ...  ..   ...     ...      ...
# 57  1610612764  Washington   Wizards  2018-19  82    32      50    0.390
# 58  1610612764  Washington   Wizards  2019-20  72    25      47    0.347
# 59  1610612764  Washington   Wizards  2020-21  72    34      38    0.472
# 60  1610612764  Washington   Wizards  2021-22  82    35      47    0.427
# 61  1610612764  Washington   Wizards  2022-23  44    18      26    0.409
#
#     CONF_RANK  DIV_RANK  ...  OREB  DREB   REB   AST    PF  STL   TOV  BLK  \
# ...

# %%
teamyearbyyearstats.TeamYearByYearStats(team_id='1610612764', ).get_data_frames()[0]

# %%
temp.get_data_frames()[0]
# Out:
#        TEAM_ID   TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612764     Chicago   Packers  1961-62  80    18      62    0.225
# 1   1610612764     Chicago   Zephyrs  1962-63  80    25      55    0.313
# 2   1610612764   Baltimore   Bullets  1963-64  80    31      49    0.388
# 3   1610612764   Baltimore   Bullets  1964-65  80    37      43    0.463
# 4   1610612764   Baltimore   Bullets  1965-66  80    38      42    0.475
# ..         ...         ...       ...      ...  ..   ...     ...      ...
# 57  1610612764  Washington   Wizards  2018-19  82    32      50    0.390
# 58  1610612764  Washington   Wizards  2019-20  72    25      47    0.347
# 59  1610612764  Washington   Wizards  2020-21  72    34      38    0.472
# 60  1610612764  Washington   Wizards  2021-22  82    35      47    0.427
# 61  1610612764  Washington   Wizards  2022-23  44    18      26    0.409
#
#     CONF_RANK  DIV_RANK  ...  OREB  DREB   REB   AST    PF  STL   TOV  BLK  \
# ...
